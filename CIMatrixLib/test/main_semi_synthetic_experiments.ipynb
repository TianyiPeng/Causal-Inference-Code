# %%
import numpy as np
import scipy as sp
import scipy.linalg
import scipy.stats
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
from sklearn.metrics import r2_score
import pickle
import time
from scipy.optimize import fsolve
from scipy.optimize import least_squares
from scipy.optimize import minimize
from scipy import sparse
import os.path
from scipy.interpolate import splrep, splev
import pandas as pd
from scipy.stats import norm
from sklearn.linear_model import LinearRegression
import sys
sys.path.append('../..')
from CIMatrixLib.src.util import *
from CIMatrixLib.src.TreatPattern import *
from CIMatrixLib.src.algorithms.RobustSyntheticControl import *
import CIMatrixLib.src.readData as readData
import importlib

sns.set_style("whitegrid")

# %% [markdown]
# ## Cleaned Notebook for Semi-Synthetic Experiments
#
# In this notebook, we cleaned the code in main.ipynb and used the causaltensor package to reproduce the Tabel 1 results in https://arxiv.org/pdf/2106.02780.pdf

# %%
pip install causaltensor==0.1.7
# Out:
# Requirement already satisfied: causaltensor==0.1.7 in /Users/tianyipeng/anaconda3/lib/python3.10/site-packages (0.1.7)
# Requirement already satisfied: numpy in /Users/tianyipeng/anaconda3/lib/python3.10/site-packages (from causaltensor==0.1.7) (1.23.5)
# Requirement already satisfied: importlib-metadata in /Users/tianyipeng/anaconda3/lib/python3.10/site-packages (from causaltensor==0.1.7) (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /Users/tianyipeng/anaconda3/lib/python3.10/site-packages (from importlib-metadata->causaltensor==0.1.7) (3.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Generate the low-rank matrix $M_0$

# %%
def synthetic_M0(n1=50, n2=50, mean_M = 1, r = 10, gamma_shape = 1, gamma_scale = 2, type = 'Gamma'): 
    '''
        generate a random rank-r non-negative (n1 x n2) matrix with mean(M) = mean_M
    '''
    if (type == 'Gamma'):
        U = np.random.gamma(shape = gamma_shape, scale = gamma_scale, size = (n1, r))
        V = np.random.gamma(shape = gamma_shape, scale = gamma_scale, size = (n2, r))
        M0 = U.dot(V.T)
        M0 = M0 / np.mean(M0) * mean_M
    else:
        if (type == 'Gaussian'):
            U = np.random.normal(loc=0, scale = 1, size = (n1, r))
            V = np.random.normal(loc = 0, scale = 1, size = (n2, r))
            M0 = mean_M * U.dot(V.T)
    return M0

# %% [markdown]
# ## Generate treatment patterns $Z$

# %%
def generate_Z(pattern_tuple = ['adaptive'], M0 = 0):
    '''
        generate the binary matrix Z for different patterns 
    '''
    while (True):
        if (pattern_tuple[0] == 'adaptive'):
            a = pattern_tuple[1][0]
            b = pattern_tuple[1][1]
            Z = adpative_treatment_pattern(a, b, M0)
    
        if (pattern_tuple[0] == 'iid'):
            p_treat = np.random.rand()*0.5
            Z = np.random.rand(n1, n2) <= p_treat

        if (pattern_tuple[0] == 'block'):
            m2 = pattern_tuple[1][1]
            Z, treat_units = simultaneous_adoption(pattern_tuple[1][0], m2, M0)
        
        if (pattern_tuple[0] == 'stagger'):
            m2 = pattern_tuple[1][1]
            Z = stagger_adoption(pattern_tuple[1][0], m2, M0)

        ## if some row or some column is all treated; or Z=0; generate Z again  
        if (np.sum(np.sum(1-Z, axis=0) == 0) > 0 or np.sum(np.sum(1-Z, axis=1) == 0) > 0 or np.sum(Z)==0): 
            if (pattern_tuple[0] == 'adaptive'):
                return Z, 'fail'
            continue
        break
    if (pattern_tuple[0] == 'block'):
        return Z, treat_units
    if (pattern_tuple[0] == 'adaptive'):
        return Z, 'success'
    return Z

# %%
from causaltensor.cauest import DID
from causaltensor.cauest import DC_PR_with_suggested_rank
from causaltensor.cauest import SDID
from causaltensor.cauest import MC_NNM_with_suggested_rank

# %%
def run_algo(algo_list, O, Z, suggest_r=-1, treat_units = [], tau_star = 0, m2 = 0, M0 = 0):
    results = {}
    for (index, algo) in enumerate(algo_list):
        if (algo == 'De-biased Convex'):
            M, tau, std = DC_PR_with_suggested_rank(O, Z, suggest_r=suggest_r)
            
        if (algo == 'MC-NNM'):
            M_b, a, b, tau = MC_NNM_with_suggested_rank(O, 1-Z, suggest_r=suggest_r)
            one_row = np.ones((1, M_b.shape[1]))
            one_col = np.ones((M_b.shape[0], 1))
            M = M_b + a.dot(one_row) + one_col.dot(b.T)

        if (algo == 'robust_synthetic_control'):  
            if (treat_units == []):
                M, tau = stagger_pattern_RSC(O, Z, suggest_r = suggest_r)
            else:
                M, tau = synthetic_control(O, suggest_r=suggest_r, treat_units=treat_units, starting_time=m2)
            #M_1, tau_1 = synthetic_control(O, suggest_r=1, treat_units=treat_units, starting_time=m2) #make the results more robust
            #if (abs(tau_1-tau_star) < abs(tau - tau_star)):
            #    M = M_1
            #    tau = tau_1
        
        if (algo == 'trivial'):
            tau = np.sum(O*Z)/np.sum(Z) - np.sum(O*(1-Z))/np.sum(1-Z)
            M = O - Z * tau

        if (algo == 'OLS'):
            M, tau = DID(O, Z, tau_star = tau_star)

        if (algo == 'ideal'):
            M = M0
            tau = np.sum((O-M0)*Z) / np.sum(Z)

        if (algo == 'SDID'):
            tau = SDID(O, Z)
            M = O - Z * tau

        results[algo] = (M, tau)
    return results

# %% [markdown]
# ## Semi-synthetic experiments on Sales data

# %%
M0 = readData.read_data('sales')
s = np.linalg.svd(M0, full_matrices=False, compute_uv=False)
#print(s)
suggest_r = 35

def sales_experiment_performance_run_results(num_experiment=1, pattern = 'adaptive', suggest_r = 1, tau_star_o = 0):
    samples = np.zeros(num_experiment)
    t1 = time.time()

    algo_list = ['De-biased Convex', 'MC-NNM', 'OLS']

    datas = np.zeros((num_experiment, len(algo_list)))

    (n1, n2) = M0.shape

    for T in range(num_experiment):
        if (T % 100 == 0):
            print(time.time() - t1)
            print('experiment ', T)
        
        if (pattern == 'adaptive'):
            while True:
                a = np.random.randint(20)+5
                b = np.random.randint(20)+5
                Z, info = generate_Z(pattern_tuple = ['adaptive', (a, b)], M0=M0)
                if (info == 'fail'):
                    continue
                break
        print('***sparsity****', np.sum(Z) / np.size(Z))


        def test():
            delta = np.random.normal(loc = 0, scale = tau_star_o / 2, size = (n1, 1)) * np.ones((n1, n2))
            d1 = np.sum(Z * delta) / np.sum(Z)
            delta = delta - d1
            tau_star = tau_star_o + d1

            O = M0 + Z*delta + tau_star * Z   

            results = run_algo(algo_list, O, Z, suggest_r = suggest_r, tau_star = tau_star, M0 = M0)
            
            error_metric = {}
            for algo in algo_list:
                (M, tau) = results[algo]
                error_metric[algo] = metric_compute(M, tau, M0, tau_star, Z, ['tau_diff'])['tau_diff']
            return error_metric

        error_metric = test()
        print(error_metric)
        for index, algo in enumerate(algo_list):
                datas[T, index] = error_metric[algo]
        print('experiment {}, time elapses '.format(T), time.time() - t1)
    datas = pd.DataFrame(datas, columns = algo_list)
    return datas


tau_star_o = np.mean(M0)/5
datas = sales_experiment_performance_run_results(num_experiment = 100, pattern = 'adaptive', suggest_r = suggest_r, tau_star_o = tau_star_o)
# Out:
# 5.0067901611328125e-06
# experiment  0
# ***sparsity**** 0.45883742718644344
# {'De-biased Convex': 119.36136456306122, 'MC-NNM': -44.335364818712605, 'OLS': -345.9704710994897}
# experiment 0, time elapses  61.60319685935974
# ***sparsity**** 0.18982443276711883
# {'De-biased Convex': 44.26054155303564, 'MC-NNM': -336.8623732580959, 'OLS': -254.53508979693288}
# experiment 1, time elapses  118.2247622013092
# ***sparsity**** 0.3570410200008147
# {'De-biased Convex': 87.42465922528527, 'MC-NNM': 172.98232105680336, 'OLS': 186.30593442684176}
# experiment 2, time elapses  178.24026799201965
# ***sparsity**** 0.27846348120086356
# {'De-biased Convex': -0.691351964572732, 'MC-NNM': -129.6770810229932, 'OLS': -195.91323803115938}
# experiment 3, time elapses  237.66384410858154
# ***sparsity**** 0.1684386329382052
# {'De-biased Convex': -21.105153437695208, 'MC-NNM': -32.12182763489545, 'OLS': -223.7774878992218}
# experiment 4, time elapses  293.0288188457489
# ***sparsity**** 0.15479245590451748
# {'De-biased Convex': -57.19712861017297, 'MC-NNM': -624.3167705382234, 'OLS': -823.6841342537639}
# experiment 5, time elapses  348.0246829986572
# ***sparsity**** 0.14851928795470284
# {'De-biased Convex': 48.44147079649065, 'MC-NNM': -103.28877529141346, 'OLS': -227.9365260834702}
# experiment 6, time elapses  403.8228950500488
# ***sparsity**** 0.4326041793963094
# {'De-biased Convex': 59.22747654619161, 'MC-NNM': -711.873795552267, 'OLS': -377.98677468872256}
# experiment 7, time elapses  439.47819805145264
# ***sparsity**** 0.2318628050022404
# {'De-biased Convex': 54.23665153227057, 'MC-NNM': -697.4239048377369, 'OLS': -1353.1895963421443}
# experiment 8, time elapses  499.7157030105591
# ***sparsity**** 0.2037557537985254
# {'De-biased Convex': -17.101126745767942, 'MC-NNM': -306.8527510436079, 'OLS': -103.2333005070268}
# experiment 9, time elapses  556.8817710876465
# ***sparsity**** 0.1532445313454723
# {'De-biased Convex': -44.94782188412137, 'MC-NNM': -75.46172206464189, 'OLS': 16.529653392257842}
# experiment 10, time elapses  613.155277967453
# ***sparsity**** 0.31834290602468535
# {'De-biased Convex': 81.73391738386954, 'MC-NNM': -607.2384214451567, 'OLS': -698.8997015264322}
# experiment 11, time elapses  672.4295620918274
# ***sparsity**** 0.2318628050022404
# {'De-biased Convex': -16.43665183245639, 'MC-NNM': -697.4239048377369, 'OLS': -1357.681661081877}
# experiment 12, time elapses  730.41836810112
# ***sparsity**** 0.4775754613222534
# {'De-biased Convex': 57.604709079203076, 'MC-NNM': 65.34453903068425, 'OLS': 247.54688284829308}
# experiment 13, time elapses  767.2458519935608
# ***sparsity**** 0.2671799258625606
# {'De-biased Convex': 99.05573421939062, 'MC-NNM': -80.1472845569665, 'OLS': 100.88567082428244}
# experiment 14, time elapses  825.1364858150482
# ***sparsity**** 0.21915352967534318
# {'De-biased Convex': 56.61049568470844, 'MC-NNM': -721.0305738074994, 'OLS': -424.94457810856557}
# experiment 15, time elapses  882.4297139644623
# ***sparsity**** 0.5191250152755713
# {'De-biased Convex': 175.59391658544519, 'MC-NNM': -342.41030049069013, 'OLS': -494.25941062906713}
# experiment 16, time elapses  945.5503568649292
# ***sparsity**** 0.34697951036702107
# {'De-biased Convex': -4.485820246183266, 'MC-NNM': 156.32309835309297, 'OLS': 395.2984035011232}
# experiment 17, time elapses  1013.5660109519958
# ***sparsity**** 0.22013116623895068
# {'De-biased Convex': -8.68917959529881, 'MC-NNM': -622.971677933718, 'OLS': -833.9724847352036}
# experiment 18, time elapses  1073.4106040000916
# ***sparsity**** 0.5614077966515948
# {'De-biased Convex': 143.98287869579053, 'MC-NNM': 293.93834395051226, 'OLS': 40.15861899594893}
# experiment 19, time elapses  1135.5718669891357
# ***sparsity**** 0.2876288239846837
# {'De-biased Convex': 41.438791855255204, 'MC-NNM': -209.99659392954027, 'OLS': 57.70353849209732}
# experiment 20, time elapses  1191.3902871608734
# ***sparsity**** 0.34697951036702107
# {'De-biased Convex': 32.73095531820309, 'MC-NNM': 156.32309835309297, 'OLS': 396.49358289276734}
# experiment 21, time elapses  1248.570140838623
# ***sparsity**** 0.31907613344739094
# {'De-biased Convex': 53.931189668154275, 'MC-NNM': -276.31687728891893, 'OLS': -756.6668856560468}
# experiment 22, time elapses  1282.3784220218658
# ***sparsity**** 0.16293942726791316
# {'De-biased Convex': -170.25022865228584, 'MC-NNM': -715.6837831388366, 'OLS': -1074.0397064032115}
# experiment 23, time elapses  1338.8410859107971
# ***sparsity**** 0.2318628050022404
# {'De-biased Convex': -6.3465107884162535, 'MC-NNM': -697.4239048377369, 'OLS': -1329.3940503008766}
# experiment 24, time elapses  1396.9638340473175
# ***sparsity**** 0.4119108721332845
# {'De-biased Convex': 103.90722386382822, 'MC-NNM': -164.42060385531113, 'OLS': -94.39446919181864}
# experiment 25, time elapses  1457.4892139434814
# ***sparsity**** 0.31716159517699294
# {'De-biased Convex': 9.758697413730715, 'MC-NNM': 244.0068264765796, 'OLS': 216.5285383199339}
# experiment 26, time elapses  1563.1346848011017
# ***sparsity**** 0.32266080084728505
# {'De-biased Convex': 60.8492787583923, 'MC-NNM': -259.8710156281709, 'OLS': 3.7620475181843176}
# experiment 27, time elapses  1692.3084490299225
# ***sparsity**** 0.14619740111613508
# {'De-biased Convex': -25.076288918348382, 'MC-NNM': -657.2380368508768, 'OLS': -869.6705485191192}
# experiment 28, time elapses  1806.382269859314
# ***sparsity**** 0.37700109984113406
# {'De-biased Convex': 165.15009912987443, 'MC-NNM': -279.27543926862154, 'OLS': 6.121287539657715}
# experiment 29, time elapses  1987.1922600269318
# ***sparsity**** 0.3177726180292476
# {'De-biased Convex': 75.16329927931201, 'MC-NNM': -56.40410261705256, 'OLS': -0.5074934446111001}
# experiment 30, time elapses  2112.184205055237
# ***sparsity**** 0.30954417695221803
# {'De-biased Convex': -16.180417666182166, 'MC-NNM': -839.5810358136246, 'OLS': -1707.9559406295057}
# experiment 31, time elapses  2195.1188428401947
# ***sparsity**** 0.3194427471587437
# {'De-biased Convex': 75.79684339368032, 'MC-NNM': -738.4642799044866, 'OLS': -1734.040861701137}
# experiment 32, time elapses  2278.569782972336
# ***sparsity**** 0.3074259643977351
# {'De-biased Convex': 30.420785461462856, 'MC-NNM': -269.4819232349282, 'OLS': 129.9795538178314}
# experiment 33, time elapses  2336.0836939811707
# ***sparsity**** 0.3773269786956699
# {'De-biased Convex': -16.624138756400498, 'MC-NNM': -588.026076252961, 'OLS': -325.7224413902709}
# experiment 34, time elapses  2395.4892580509186
# ***sparsity**** 0.251456271131207
# {'De-biased Convex': 120.20207111253922, 'MC-NNM': -484.2321396234736, 'OLS': -577.0010979859542}
# experiment 35, time elapses  2452.3789999485016
# ***sparsity**** 0.3497494806305756
# {'De-biased Convex': 66.70259651334891, 'MC-NNM': -264.556313941041, 'OLS': 123.58574673746762}
# experiment 36, time elapses  2509.866688013077
# ***sparsity**** 0.22583404619332764
# {'De-biased Convex': 55.62713722569515, 'MC-NNM': -837.2414907043303, 'OLS': -1248.3038810728278}
# experiment 37, time elapses  2565.427486896515
# ***sparsity**** 0.33744755387184816
# {'De-biased Convex': 46.23475963234887, 'MC-NNM': -973.8201848150741, 'OLS': -1564.1304727896672}
# experiment 38, time elapses  2648.2346711158752
# ***sparsity**** 0.328322945944845
# {'De-biased Convex': 7.128535838840435, 'MC-NNM': -865.5613997619655, 'OLS': -1468.700280941832}
# experiment 39, time elapses  2732.3930361270905
# ***sparsity**** 0.46335899629312804
# {'De-biased Convex': 78.88485547383789, 'MC-NNM': -484.6173346094786, 'OLS': -118.41044833062688}
# experiment 40, time elapses  2797.612860918045
# ***sparsity**** 0.5118334759053322
# {'De-biased Convex': 93.72835582148582, 'MC-NNM': 105.50688603343633, 'OLS': -378.5635121641094}
# experiment 41, time elapses  2861.413918018341
# ***sparsity**** 0.21112876288239846
# {'De-biased Convex': -96.65660303271034, 'MC-NNM': -607.6495113705937, 'OLS': -944.4210300673828}
# experiment 42, time elapses  2919.9302270412445
# ***sparsity**** 0.3365513870218746
# {'De-biased Convex': 4.1501410155324265, 'MC-NNM': 199.12462594106273, 'OLS': 145.51981325615134}
# experiment 43, time elapses  2980.5301299095154
# ***sparsity**** 0.1420424457208033
# {'De-biased Convex': -11.558712590885534, 'MC-NNM': -183.25177562235012, 'OLS': -127.62493525902255}
# experiment 44, time elapses  3038.152370929718
# ***sparsity**** 0.47741252189498556
# {'De-biased Convex': -49.7393223971676, 'MC-NNM': -282.35579799044126, 'OLS': -732.6135085632648}
# experiment 45, time elapses  3102.4766280651093
# ***sparsity**** 0.49354352519450895
# {'De-biased Convex': -100.3388546968572, 'MC-NNM': -29.65691899306057, 'OLS': -452.3273990706157}
# experiment 46, time elapses  3166.500524997711
# ***sparsity**** 0.47696443846999875
# {'De-biased Convex': 44.45000056364279, 'MC-NNM': -534.8840452961736, 'OLS': -312.0622414800546}
# experiment 47, time elapses  3228.2831859588623
# ***sparsity**** 0.29129496109821174
# {'De-biased Convex': 16.957176013103435, 'MC-NNM': -307.7610170974858, 'OLS': -624.7902959792475}
# experiment 48, time elapses  3290.7767522335052
# ***sparsity**** 0.13878365717544502
# {'De-biased Convex': -17.083685081494878, 'MC-NNM': -600.226085525321, 'OLS': -782.483946713178}
# experiment 49, time elapses  3347.185982942581
# ***sparsity**** 0.4879221149537659
# {'De-biased Convex': -92.28554697102118, 'MC-NNM': -401.04327865959544, 'OLS': -45.37655247244629}
# experiment 50, time elapses  3411.7416179180145
# ***sparsity**** 0.2059961709234592
# {'De-biased Convex': 9.308981145392863, 'MC-NNM': -605.1857717159401, 'OLS': -781.7367180219692}
# experiment 51, time elapses  3469.660645008087
# ***sparsity**** 0.19459041101470528
# {'De-biased Convex': -61.31881044907777, 'MC-NNM': -578.3385340984428, 'OLS': -406.1205203092436}
# experiment 52, time elapses  3525.355849981308
# ***sparsity**** 0.45024237239806103
# {'De-biased Convex': 6.289285888883114, 'MC-NNM': -296.40049233490026, 'OLS': 12.495051076984055}
# experiment 53, time elapses  3560.606961965561
# ***sparsity**** 0.371461159314025
# {'De-biased Convex': 105.29332468220264, 'MC-NNM': -417.88939819740926, 'OLS': -359.7869488658157}
# experiment 54, time elapses  3619.151922941208
# ***sparsity**** 0.37757138783657174
# {'De-biased Convex': 60.70926878428463, 'MC-NNM': 385.96357428719693, 'OLS': 222.45698276839448}
# experiment 55, time elapses  3656.0653398036957
# ***sparsity**** 0.328322945944845
# {'De-biased Convex': 94.66501927763375, 'MC-NNM': -865.561399761965, 'OLS': -1457.9082699144883}
# experiment 56, time elapses  3740.3031628131866
# ***sparsity**** 0.5016904965579047
# {'De-biased Convex': 90.00809287602851, 'MC-NNM': -423.8472060656575, 'OLS': -373.6933421385422}
# experiment 57, time elapses  3804.7026088237762
# ***sparsity**** 0.3422135321194346
# {'De-biased Convex': -26.544140221350972, 'MC-NNM': -330.95803564689595, 'OLS': -182.4323990581397}
# experiment 58, time elapses  3867.7003309726715
# ***sparsity**** 0.16293942726791316
# {'De-biased Convex': -93.43188362216142, 'MC-NNM': -715.6837831388368, 'OLS': -1065.1161885842207}
# experiment 59, time elapses  3925.9543328285217
# ***sparsity**** 0.23243309299767811
# {'De-biased Convex': 13.01370465068294, 'MC-NNM': -104.6450118976777, 'OLS': 45.05526764376964}
# experiment 60, time elapses  3984.9321229457855
# ***sparsity**** 0.298301356470732
# {'De-biased Convex': 1.4553066120097355, 'MC-NNM': -90.95480439063977, 'OLS': 172.46757867185488}
# experiment 61, time elapses  4044.4064588546753
# ***sparsity**** 0.13878365717544502
# {'De-biased Convex': -131.27886063538836, 'MC-NNM': -600.226085525321, 'OLS': -777.7199426601135}
# experiment 62, time elapses  4133.869070053101
# ***sparsity**** 0.30107132673428655
# {'De-biased Convex': 36.85459774023866, 'MC-NNM': -832.6723582584314, 'OLS': -1758.281168683529}
# experiment 63, time elapses  4258.48433303833
# ***sparsity**** 0.3038005621410241
# {'De-biased Convex': 74.70483479779023, 'MC-NNM': -793.2579345617917, 'OLS': -1771.2989203809193}
# experiment 64, time elapses  4381.7070388793945
# ***sparsity**** 0.41235895555827123
# {'De-biased Convex': 82.24745176878605, 'MC-NNM': 545.7932421781256, 'OLS': 402.0168828418573}
# experiment 65, time elapses  4422.958918809891
# ***sparsity**** 0.35264165546458104
# {'De-biased Convex': -2.9131137192593997, 'MC-NNM': -222.34542898022346, 'OLS': -596.3700054875283}
# experiment 66, time elapses  4464.216207027435
# ***sparsity**** 0.3886512688907898
# {'De-biased Convex': 120.86413783879516, 'MC-NNM': 185.26832581209965, 'OLS': 124.42791094643326}
# experiment 67, time elapses  4500.234149932861
# ***sparsity**** 0.31834290602468535
# {'De-biased Convex': 97.72609535467154, 'MC-NNM': -607.2384214451567, 'OLS': -703.3972967081393}
# experiment 68, time elapses  4560.234479188919
# ***sparsity**** 0.19459041101470528
# {'De-biased Convex': -47.008150661632044, 'MC-NNM': -578.3385340984435, 'OLS': -422.1044877876527}
# experiment 69, time elapses  4619.63819694519
# ***sparsity**** 0.16293942726791316
# {'De-biased Convex': -92.91891597456652, 'MC-NNM': -715.683783138837, 'OLS': -1071.1691365705547}
# experiment 70, time elapses  4682.841886043549
# ***sparsity**** 0.3031895392887694
# {'De-biased Convex': -73.85761197549346, 'MC-NNM': -416.2984894511253, 'OLS': -812.9612636240695}
# experiment 71, time elapses  4745.152930021286
# ***sparsity**** 0.6310644018086277
# {'De-biased Convex': 125.49468799895703, 'MC-NNM': -215.7043087999441, 'OLS': -353.3086034866242}
# experiment 72, time elapses  4794.696474790573
# ***sparsity**** 0.23349219927491954
# {'De-biased Convex': -7.718156247401112, 'MC-NNM': -516.6241091930626, 'OLS': -138.4505554430193}
# experiment 73, time elapses  4854.517882823944
# ***sparsity**** 0.15972137357937186
# {'De-biased Convex': -127.39229497889937, 'MC-NNM': -102.71824303801623, 'OLS': -207.78080069024736}
# experiment 74, time elapses  4914.650288820267
# ***sparsity**** 0.5034828302578517
# {'De-biased Convex': 89.11486640908106, 'MC-NNM': -395.301547489325, 'OLS': -543.1553136593029}
# experiment 75, time elapses  4980.378987073898
# ***sparsity**** 0.20721821662796855
# {'De-biased Convex': -22.25731858604422, 'MC-NNM': -612.9929142374519, 'OLS': -283.9522343681024}
# experiment 76, time elapses  5042.570972919464
# ***sparsity**** 0.21112876288239846
# {'De-biased Convex': -55.61693388915364, 'MC-NNM': -607.6495113705935, 'OLS': -927.1849837384723}
# experiment 77, time elapses  5103.192496776581
# ***sparsity**** 0.12061591103507271
# {'De-biased Convex': -19.139966112393267, 'MC-NNM': -4.910346248968381, 'OLS': -226.0277681965108}
# experiment 78, time elapses  5162.090511083603
# ***sparsity**** 0.45883742718644344
# {'De-biased Convex': -13.112029420506133, 'MC-NNM': -44.33536481871306, 'OLS': -344.55384458718254}
# experiment 79, time elapses  5227.388112783432
# ***sparsity**** 0.3326815756242617
# {'De-biased Convex': -24.406446908609723, 'MC-NNM': -312.7856439051129, 'OLS': -700.6148133564482}
# experiment 80, time elapses  5291.815582036972
# ***sparsity**** 0.4775754613222534
# {'De-biased Convex': 74.29727496075066, 'MC-NNM': 65.34453903068379, 'OLS': 223.4280413857814}
# experiment 81, time elapses  5333.229460954666
# ***sparsity**** 0.24982687685852784
# {'De-biased Convex': 16.289575676532422, 'MC-NNM': -322.28379405311625, 'OLS': -544.3319178561467}
# experiment 82, time elapses  5395.1518268585205
# ***sparsity**** 0.15972137357937186
# {'De-biased Convex': -10.479135789874817, 'MC-NNM': -102.71824303801577, 'OLS': -213.0066362341654}
# experiment 83, time elapses  5454.5616319179535
# ***sparsity**** 0.13344739093242086
# {'De-biased Convex': 0.7046847546566823, 'MC-NNM': -34.05309235612776, 'OLS': -37.42772949174241}
# experiment 84, time elapses  5513.798556804657
# ***sparsity**** 0.14851928795470284
# {'De-biased Convex': 2.5267107835525167, 'MC-NNM': -103.288775291413, 'OLS': -224.9670221783731}
# experiment 85, time elapses  5569.992066144943
# ***sparsity**** 0.23349219927491954
# {'De-biased Convex': -22.035367148095247, 'MC-NNM': -516.6241091930628, 'OLS': -134.92061609822167}
# experiment 86, time elapses  5627.935134887695
# ***sparsity**** 0.3989164528086684
# {'De-biased Convex': 100.44340482955431, 'MC-NNM': -656.112104742874, 'OLS': -309.0769499705111}
# experiment 87, time elapses  5689.217727899551
# ***sparsity**** 0.1789889608538026
# {'De-biased Convex': 19.203022516592227, 'MC-NNM': -502.1228798645145, 'OLS': -316.7414665417366}
# experiment 88, time elapses  5747.01437997818
# ***sparsity**** 0.5606338343720721
# {'De-biased Convex': 160.8906297341091, 'MC-NNM': -157.20558963622534, 'OLS': -216.078835320694}
# experiment 89, time elapses  5787.3171598911285
# ***sparsity**** 0.35455619373497904
# {'De-biased Convex': -137.7889139866502, 'MC-NNM': 66.35151326397772, 'OLS': 79.06284967237525}
# experiment 90, time elapses  5848.0175931453705
# ***sparsity**** 0.4003829076540796
# {'De-biased Convex': 38.32897997424334, 'MC-NNM': -38.26867529909305, 'OLS': -57.51101101547647}
# experiment 91, time elapses  5909.75625705719
# ***sparsity**** 0.20721821662796855
# {'De-biased Convex': 80.31559143826735, 'MC-NNM': -612.9929142374519, 'OLS': -281.59548269386823}
# experiment 92, time elapses  5970.13459610939
# ***sparsity**** 0.2981384170434641
# {'De-biased Convex': 1.331695886856778, 'MC-NNM': -758.2575520738039, 'OLS': -1639.220702102647}
# experiment 93, time elapses  6054.889198064804
# ***sparsity**** 0.1619210558474887
# {'De-biased Convex': -45.14508174622779, 'MC-NNM': -653.9152799947028, 'OLS': -742.3794921166752}
# experiment 94, time elapses  6113.138377904892
# ***sparsity**** 0.4101185384333374
# {'De-biased Convex': 140.31547374627598, 'MC-NNM': -231.23563679917424, 'OLS': -322.36812248055185}
# experiment 95, time elapses  6150.7036809921265
# ***sparsity**** 0.3912175648702595
# {'De-biased Convex': 141.19967097024664, 'MC-NNM': -377.9232446219048, 'OLS': -416.8835318090928}
# experiment 96, time elapses  6188.7708568573
# ***sparsity**** 0.21939793881624506
# {'De-biased Convex': 65.40020069244974, 'MC-NNM': -244.6345014785743, 'OLS': -112.37468568731174}
# experiment 97, time elapses  6249.605751991272
# ***sparsity**** 0.3074259643977351
# {'De-biased Convex': 115.17555700538833, 'MC-NNM': -269.48192323492776, 'OLS': 144.7529663571022}
# experiment 98, time elapses  6310.832231998444
# ***sparsity**** 0.5768463073852296
# {'De-biased Convex': 118.14674149082248, 'MC-NNM': -391.25591151977596, 'OLS': -927.8435801268358}
# experiment 99, time elapses  6379.910749912262

# %%
(np.abs(datas) / tau_star_o).describe()
# Out:
#        De-biased Convex      MC-NNM         OLS
# count        100.000000  100.000000  100.000000
# mean           0.024979    0.161725    0.210507
# std            0.018946    0.104833    0.193478
# min            0.000284    0.002017    0.000208
# 25%            0.007024    0.070187    0.068087
# 50%            0.022851    0.139532    0.143642
# 75%            0.038415    0.249639    0.313022
# max            0.072139    0.400072    0.727699

# %% [markdown]
# ## Semi-synthetic experiments on Tobacco data

# %%
def tobacco_experiment_performance_run_results(num_experiment=1, sigma = 0.1, pattern = 'block', suggest_r = 10, row_specific=False):
    t1 = time.time()

    algo_list = ['De-biased Convex', 'SDID', 'MC-NNM', 'robust_synthetic_control', 'OLS']

    datas = np.zeros((num_experiment, len(algo_list)))

    (n1, n2) = M0.shape

    for T in range(num_experiment):
        if (T % 100 == 0):
            print(time.time() - t1)
            print('experiment ', T)

        ## generating stagger pattern Z
        if (pattern == 'stagger'):
            m1 = np.random.randint(low=1, high=n1)
            m2 = np.random.randint(low=1, high=n2)
            Z = generate_Z(pattern_tuple=['stagger', (m1, m2)], M0=M0)
            treat_units = []

        if (pattern == 'block'):
            #m1 = np.random.randint(low=1, high=int(n1/3))
            #m2 = np.random.randint(low=int(n2/2), high=n2)
            m1 = np.random.randint(low=1, high=5)
            m2 = 18
            Z, treat_units = generate_Z(pattern_tuple=['block', (m1, m2)], M0=M0)
            print('***sparsity****', np.sum(Z) / np.size(Z))

        def test():

            #M0, M1, E = synthetic_intervention_pattern()
            delta = np.random.normal(loc = 0, scale = tau_star_o / 2, size = (n1, 1)) * np.ones((n1, n2))
            #print(delta)
            d1 = np.sum(Z * delta) / np.sum(Z)
            delta = delta - d1
            tau_star = tau_star_o + d1

            O = M0 + Z*delta + tau_star * Z 
            
            results = run_algo(algo_list, O, Z, suggest_r = suggest_r, treat_units=treat_units, tau_star = tau_star, m2 = m2, M0 = M0)


            error_metric = {}
            for algo in algo_list:
                (M, tau) = results[algo]
                error_metric[algo] = metric_compute(M, tau, M0, tau_star, Z, ['tau_diff'])['tau_diff']
            
            return error_metric

        error_metric = test()
        print(error_metric)
        for index, algo in enumerate(algo_list):
                datas[T, index] = error_metric[algo]
        print('experiment {}, time elapses '.format(T), time.time() - t1)
    datas = pd.DataFrame(datas, columns = algo_list)
    return datas

M0 = readData.read_data('tobacco')
suggest_r = 5
tau_star_o = np.mean(M0) / 5
datas = tobacco_experiment_performance_run_results(num_experiment = 100, pattern = 'stagger', suggest_r = suggest_r)
# Out:
# 3.0994415283203125e-06
# experiment  0
# {'De-biased Convex': -1.4086585070538717, 'SDID': -11.583023929340628, 'MC-NNM': -8.476170089953191, 'robust_synthetic_control': -9.883489101804308, 'OLS': -7.265871878499794}
# experiment 0, time elapses  10.003129243850708
# {'De-biased Convex': -0.7386708703147207, 'SDID': -4.950631227388357, 'MC-NNM': -7.817709697042961, 'robust_synthetic_control': 0.20256873318528434, 'OLS': -12.35075877693222}
# experiment 1, time elapses  19.976001024246216
# {'De-biased Convex': 6.000168455199422, 'SDID': -0.43612063738395435, 'MC-NNM': 2.2231631419361833, 'robust_synthetic_control': 2.064237405923109, 'OLS': 0.09596083883039697}
# experiment 2, time elapses  26.132344245910645
# {'De-biased Convex': -1.5662981363313797, 'SDID': -2.0012248618727853, 'MC-NNM': -0.6167917208729392, 'robust_synthetic_control': 0.16320663631941912, 'OLS': -1.324566132238676}
# experiment 3, time elapses  31.638011932373047
# {'De-biased Convex': -3.3260405743948525, 'SDID': 7.572842385867222, 'MC-NNM': 7.846032811328609, 'robust_synthetic_control': 15.339748679053866, 'OLS': 6.713500021085295}
# experiment 4, time elapses  35.65598106384277
# {'De-biased Convex': -2.4051292564828906, 'SDID': 0.17971854189545056, 'MC-NNM': 3.0333723226565112, 'robust_synthetic_control': 1.577455808249617, 'OLS': 6.632487707322202}
# experiment 5, time elapses  39.49264693260193
# {'De-biased Convex': -1.3783224788532387, 'SDID': -1.2691468288091485, 'MC-NNM': -3.883318370006023, 'robust_synthetic_control': -4.860487064469847, 'OLS': -0.8297062019457009}
# experiment 6, time elapses  45.0464141368866
# {'De-biased Convex': -1.8305286642692487, 'SDID': -10.404341099675769, 'MC-NNM': -7.598865911403465, 'robust_synthetic_control': -2.422663050893483, 'OLS': -5.651718868741529}
# experiment 7, time elapses  60.43591094017029
# {'De-biased Convex': 0.8366399024589519, 'SDID': 0.14270958936885947, 'MC-NNM': -10.046400124002986, 'robust_synthetic_control': -2.1289119653662034, 'OLS': -10.14587763860687}
# experiment 8, time elapses  77.22313499450684
# {'De-biased Convex': -3.2088573407435277, 'SDID': -3.0305369770914794, 'MC-NNM': -3.0418827337522494, 'robust_synthetic_control': -3.6861334468629785, 'OLS': -1.6280387473559728}
# experiment 9, time elapses  81.7977249622345
# {'De-biased Convex': -3.7398221269837, 'SDID': -3.201090728210044, 'MC-NNM': -9.641098861617909, 'robust_synthetic_control': -7.286368011147047, 'OLS': -10.395887194511356}
# experiment 10, time elapses  93.22129225730896
# {'De-biased Convex': 1.6479179369617682, 'SDID': 3.5817893017449904, 'MC-NNM': 1.7161142283615405, 'robust_synthetic_control': 9.577160050063124, 'OLS': 4.063654035078219}
# experiment 11, time elapses  104.02291107177734
# {'De-biased Convex': -1.977666458358069, 'SDID': 5.063754325014145, 'MC-NNM': -0.22474697782718778, 'robust_synthetic_control': 7.785012092623624, 'OLS': -2.882824457864274}
# experiment 12, time elapses  112.51840209960938
# {'De-biased Convex': -0.97047525537306, 'SDID': -3.287364299307505, 'MC-NNM': -3.8588737041146537, 'robust_synthetic_control': -1.0908752329587301, 'OLS': -5.555435086503152}
# experiment 13, time elapses  119.40203499794006
# {'De-biased Convex': -2.171321406103793, 'SDID': 6.715811259398578, 'MC-NNM': 2.666928185144748, 'robust_synthetic_control': -12.931556107209055, 'OLS': 11.627618747510532}
# experiment 14, time elapses  125.56435704231262
# {'De-biased Convex': 1.2241086156866494, 'SDID': -2.5005511086866825, 'MC-NNM': -10.6307806436236, 'robust_synthetic_control': -0.8052695064406841, 'OLS': -9.830313541960566}
# experiment 15, time elapses  139.15187692642212
# {'De-biased Convex': 2.356377004837256, 'SDID': 2.347076331220933, 'MC-NNM': -2.038165954623402, 'robust_synthetic_control': -7.863588363598961, 'OLS': -1.8866187655116562}
# experiment 16, time elapses  150.5386462211609
# {'De-biased Convex': 2.595174365172607, 'SDID': 2.122972427483262, 'MC-NNM': -1.7484168308813217, 'robust_synthetic_control': 3.10348208529906, 'OLS': -0.7541354900227795}
# experiment 17, time elapses  156.72652912139893
# {'De-biased Convex': 1.8078427680448925, 'SDID': -5.021458482584553, 'MC-NNM': -5.323503342902704, 'robust_synthetic_control': -1.867485821946829, 'OLS': -5.366455851867981}
# experiment 18, time elapses  166.62264204025269
# {'De-biased Convex': 2.130401865837797, 'SDID': -0.6338426124132006, 'MC-NNM': 0.20771456534298238, 'robust_synthetic_control': 3.6753634112556917, 'OLS': -2.663015593293739}
# experiment 19, time elapses  178.83868718147278
# {'De-biased Convex': 6.301933497353586, 'SDID': 5.572882536303782, 'MC-NNM': 7.451534676560607, 'robust_synthetic_control': 0.6269871847426263, 'OLS': 8.837698534086437}
# experiment 20, time elapses  183.4512882232666
# {'De-biased Convex': -3.3583387034011167, 'SDID': -8.294932253075487, 'MC-NNM': -0.5050910631751186, 'robust_synthetic_control': 4.539730269090484, 'OLS': -7.655906894101221}
# experiment 21, time elapses  197.3584451675415
# {'De-biased Convex': -0.06779248249583958, 'SDID': -0.7046306453892441, 'MC-NNM': 1.0936170321380274, 'robust_synthetic_control': -1.6824189166135497, 'OLS': 3.866780575779053}
# experiment 22, time elapses  205.2407670021057
# {'De-biased Convex': -0.02159170740419114, 'SDID': -7.872654502346446, 'MC-NNM': -3.515478463620269, 'robust_synthetic_control': -11.776087935606848, 'OLS': -3.5431330874737057}
# experiment 23, time elapses  217.28709888458252
# {'De-biased Convex': -1.5498572873242153, 'SDID': 5.775154169446424, 'MC-NNM': 8.009466356268774, 'robust_synthetic_control': 10.392114453004453, 'OLS': 8.60878677711072}
# experiment 24, time elapses  219.785551071167
# {'De-biased Convex': -0.37047405588843674, 'SDID': 0.3011441476514136, 'MC-NNM': -1.2724754067797654, 'robust_synthetic_control': 52.27592341270968, 'OLS': -0.9850971737353937}
# experiment 25, time elapses  232.35694694519043
# {'De-biased Convex': 0.6656567116421037, 'SDID': 0.027162057670697237, 'MC-NNM': 1.4035635332564738, 'robust_synthetic_control': -4.947685146445714, 'OLS': 3.7625221799838258}
# experiment 26, time elapses  243.44110798835754
# {'De-biased Convex': 0.4928677750882926, 'SDID': -4.647497506875119, 'MC-NNM': -6.074625966551071, 'robust_synthetic_control': 3.90205058760721, 'OLS': -1.735946858954648}
# experiment 27, time elapses  258.3484070301056
# {'De-biased Convex': -1.2600393202848466, 'SDID': -1.6917619848148817, 'MC-NNM': -1.545209402490805, 'robust_synthetic_control': 4.623572451012674, 'OLS': 0.18804962841417705}
# experiment 28, time elapses  272.61628699302673
# {'De-biased Convex': 3.390751186043797, 'SDID': -5.982852708750421, 'MC-NNM': -0.9331396097717182, 'robust_synthetic_control': 3.6433292631566623, 'OLS': -1.6062824831679876}
# experiment 29, time elapses  287.284419298172
# {'De-biased Convex': -0.4366047267114084, 'SDID': 0.2235527624964071, 'MC-NNM': 2.2163012800256574, 'robust_synthetic_control': 0.21611109304847176, 'OLS': 4.3243955878192715}
# experiment 30, time elapses  289.0328290462494
# {'De-biased Convex': -8.56322178920621, 'SDID': -11.404544324092313, 'MC-NNM': -3.283134549126572, 'robust_synthetic_control': -5.839822192909441, 'OLS': 0.17694894031829023}
# experiment 31, time elapses  290.6956310272217
# {'De-biased Convex': 3.677526420877765, 'SDID': -1.4361741340699794, 'MC-NNM': -4.339507801298014, 'robust_synthetic_control': -6.750784424780809, 'OLS': -4.304841012493251}
# experiment 32, time elapses  296.8581910133362
# {'De-biased Convex': 2.008514948145521, 'SDID': 3.214625816843668, 'MC-NNM': 4.657715097446882, 'robust_synthetic_control': 2.6342218446053742, 'OLS': 0.9349975072763073}
# experiment 33, time elapses  307.71830105781555
# {'De-biased Convex': 4.500704846459708, 'SDID': 2.6318892066403237, 'MC-NNM': 2.166026843463282, 'robust_synthetic_control': 3.779192232767155, 'OLS': 4.440868421309634}
# experiment 34, time elapses  314.6758711338043
# {'De-biased Convex': -0.04025634926832211, 'SDID': -6.852534987284653, 'MC-NNM': -7.422176341137305, 'robust_synthetic_control': 1.6020332272778042, 'OLS': -3.8206305673048426}
# experiment 35, time elapses  325.6786079406738
# {'De-biased Convex': -0.7473695118772561, 'SDID': -5.274160593238683, 'MC-NNM': -9.067082025951237, 'robust_synthetic_control': -8.344199589491787, 'OLS': -14.139220133726136}
# experiment 36, time elapses  334.0715479850769
# {'De-biased Convex': 2.4887900352264474, 'SDID': 6.601659842973163, 'MC-NNM': 6.179313785323167, 'robust_synthetic_control': -0.5186747341087212, 'OLS': 7.263836516564137}
# experiment 37, time elapses  342.58863592147827
# {'De-biased Convex': 0.7858781995516502, 'SDID': 2.9835162860114757, 'MC-NNM': 6.997572034499459, 'robust_synthetic_control': -20.410430036974105, 'OLS': 9.411228468251242}
# experiment 38, time elapses  345.9607529640198
# {'De-biased Convex': -5.685156973919305, 'SDID': -5.79041629684556, 'MC-NNM': -3.4182160060984685, 'robust_synthetic_control': -1.760426787003194, 'OLS': -6.5368600604279585}
# experiment 39, time elapses  352.0653929710388
# {'De-biased Convex': -1.1158505385944508, 'SDID': 2.6747237026125426, 'MC-NNM': 4.924572345997802, 'robust_synthetic_control': 20.064596792363545, 'OLS': 7.990821506083726}
# experiment 40, time elapses  356.1604940891266
# {'De-biased Convex': 1.2392851339994984, 'SDID': -3.8264866400229103, 'MC-NNM': 0.46199857620111473, 'robust_synthetic_control': -1.1456409782904906, 'OLS': -1.7413806065558823}
# experiment 41, time elapses  367.6630439758301
# {'De-biased Convex': 1.2007812561505666, 'SDID': 4.053533686675376, 'MC-NNM': -1.7546686418826312, 'robust_synthetic_control': 8.925912385081968, 'OLS': -5.941474726774665}
# experiment 42, time elapses  373.98898100852966
# {'De-biased Convex': 2.483601471851234, 'SDID': -2.634991929612628, 'MC-NNM': 2.5899479798106313, 'robust_synthetic_control': -1.378975127284395, 'OLS': 5.4226448532884035}
# experiment 43, time elapses  382.470232963562
# {'De-biased Convex': -3.9441215205339333, 'SDID': 1.72362129194752, 'MC-NNM': 9.570279257665636, 'robust_synthetic_control': 8.114350526685005, 'OLS': 7.08588817061548}
# experiment 44, time elapses  386.4046289920807
# {'De-biased Convex': 1.523796786249168, 'SDID': -3.4970408073580472, 'MC-NNM': -3.4740727812020538, 'robust_synthetic_control': -2.4928886903556737, 'OLS': -3.0438451523933914}
# experiment 45, time elapses  398.1915590763092
# {'De-biased Convex': 2.074313497878279, 'SDID': -6.141121101286547, 'MC-NNM': -9.014577212716066, 'robust_synthetic_control': -1.1446868790763887, 'OLS': -12.944686066379536}
# experiment 46, time elapses  411.1639618873596
# {'De-biased Convex': -5.716914039719985, 'SDID': -12.317593927945822, 'MC-NNM': 1.3744908242944156, 'robust_synthetic_control': 11.875517837033737, 'OLS': 2.9326403525425455}
# experiment 47, time elapses  418.1737570762634
# {'De-biased Convex': -3.283542507657806, 'SDID': -10.359890850215162, 'MC-NNM': -0.27496536938956595, 'robust_synthetic_control': -2.456580881895551, 'OLS': 0.881918978716687}
# experiment 48, time elapses  422.81227922439575
# {'De-biased Convex': 5.097321180996673, 'SDID': -5.638077979162809, 'MC-NNM': -6.52310473157671, 'robust_synthetic_control': 12.439250030956302, 'OLS': -10.098413981190758}
# experiment 49, time elapses  431.93603801727295
# {'De-biased Convex': -1.0246505002464268, 'SDID': -5.221352703222951, 'MC-NNM': -2.3009104289102105, 'robust_synthetic_control': -5.330497749164582, 'OLS': -0.3034673768720957}
# experiment 50, time elapses  441.2864110469818
# {'De-biased Convex': -2.064119022333788, 'SDID': -5.420252335256393, 'MC-NNM': -2.4242295975893526, 'robust_synthetic_control': 1.274707374004965, 'OLS': 0.04509937931385721}
# experiment 51, time elapses  445.8404932022095
# {'De-biased Convex': -5.2195392312972295, 'SDID': -5.685042372430949, 'MC-NNM': -2.1918577357940876, 'robust_synthetic_control': -4.681719787975808, 'OLS': -2.6981305497928716}
# experiment 52, time elapses  448.89818716049194
# {'De-biased Convex': 5.874019090368458, 'SDID': 10.056651695007892, 'MC-NNM': 4.739739086646422, 'robust_synthetic_control': 4.7227762307564465, 'OLS': 8.667331916499817}
# experiment 53, time elapses  458.0899341106415
# {'De-biased Convex': 0.17495567407420864, 'SDID': -1.0675024519611398, 'MC-NNM': -0.4414440708436338, 'robust_synthetic_control': -0.7273554083553471, 'OLS': -0.925974531270775}
# experiment 54, time elapses  461.26640009880066
# {'De-biased Convex': -0.7394251650864199, 'SDID': -2.162269617878678, 'MC-NNM': 16.30659267595886, 'robust_synthetic_control': -1.4632214839447606, 'OLS': 12.387365747298105}
# experiment 55, time elapses  466.7708270549774
# {'De-biased Convex': 0.5512384552713918, 'SDID': -0.6334562782059088, 'MC-NNM': 0.13913620296025186, 'robust_synthetic_control': 0.09878555920109378, 'OLS': -0.7563131365184041}
# experiment 56, time elapses  482.7951021194458
# {'De-biased Convex': 3.495553606095825, 'SDID': 3.265791462524259, 'MC-NNM': 5.683801115675632, 'robust_synthetic_control': -3.7614305563907884, 'OLS': 10.112500398601032}
# experiment 57, time elapses  488.8801281452179
# {'De-biased Convex': -1.328984135527005, 'SDID': -0.8722092142719866, 'MC-NNM': 4.076259338015738, 'robust_synthetic_control': 3.666592721855089, 'OLS': 7.254259580768839}
# experiment 58, time elapses  491.29494309425354
# {'De-biased Convex': -6.791927389677092, 'SDID': -4.706730617363256, 'MC-NNM': -3.9297946420909398, 'robust_synthetic_control': -1.2575420665877068, 'OLS': -5.6860769251494805}
# experiment 59, time elapses  499.6294119358063
# {'De-biased Convex': -1.140591891729212, 'SDID': -2.4420388968469027, 'MC-NNM': 0.02825970307384651, 'robust_synthetic_control': 6.584842821467856, 'OLS': -1.7732947841304743}
# experiment 60, time elapses  510.16852617263794
# {'De-biased Convex': -4.000648482732689, 'SDID': -4.39155321978123, 'MC-NNM': -0.08882297964713715, 'robust_synthetic_control': -3.383861873212318, 'OLS': 7.543019559420216}
# experiment 61, time elapses  510.31334114074707
# {'De-biased Convex': 0.7656223768318569, 'SDID': -3.11304561428107, 'MC-NNM': -4.062796292253534, 'robust_synthetic_control': -5.354849460569991, 'OLS': -2.6249337097025}
# experiment 62, time elapses  519.5531129837036
# {'De-biased Convex': -0.1771300581823887, 'SDID': -3.7140304525211665, 'MC-NNM': 0.5874652967570668, 'robust_synthetic_control': -3.301391720607061, 'OLS': 4.199447116363885}
# experiment 63, time elapses  524.2066481113434
# {'De-biased Convex': 1.6391863973416285, 'SDID': -5.278869211439925, 'MC-NNM': -7.0374209037705935, 'robust_synthetic_control': -9.162786449282361, 'OLS': -5.62936902967261}
# experiment 64, time elapses  536.4070670604706
# {'De-biased Convex': 3.2371376040836495, 'SDID': 3.28005470677569, 'MC-NNM': -1.3760054167586588, 'robust_synthetic_control': 1.411959645516852, 'OLS': 0.6057202800084518}
# experiment 65, time elapses  544.17888712883
# {'De-biased Convex': -0.35762833422922924, 'SDID': 1.2255762464669893, 'MC-NNM': 1.6589076188035499, 'robust_synthetic_control': -4.330446236442988, 'OLS': 5.538637585614566}
# experiment 66, time elapses  556.0458340644836
# {'De-biased Convex': 1.9574207433212507, 'SDID': 1.0976929637616877, 'MC-NNM': 1.334020604391437, 'robust_synthetic_control': 4.936199993106396, 'OLS': 0.9480795144906757}
# experiment 67, time elapses  566.2017018795013
# {'De-biased Convex': 0.22908698000144412, 'SDID': -8.117008067832169, 'MC-NNM': 5.056694134165593, 'robust_synthetic_control': -2.3500423807655224, 'OLS': 4.798959044983352}
# experiment 68, time elapses  571.8168909549713
# {'De-biased Convex': 3.7394341380893366, 'SDID': 4.941711696068399, 'MC-NNM': -1.6563682467148553, 'robust_synthetic_control': -2.6636683684478406, 'OLS': 6.257429874911686}
# experiment 69, time elapses  584.7139310836792
# {'De-biased Convex': -4.384539780889007, 'SDID': 0.42420455009888514, 'MC-NNM': 2.265112115469787, 'robust_synthetic_control': 0.9840183751912157, 'OLS': 3.319975199345105}
# experiment 70, time elapses  585.0323050022125
# {'De-biased Convex': -1.8058509685189534, 'SDID': -4.953570055436792, 'MC-NNM': -3.252233783091807, 'robust_synthetic_control': -1.7362982317909221, 'OLS': -2.980425191040812}
# experiment 71, time elapses  596.544643163681
# {'De-biased Convex': 1.6027701317842116, 'SDID': -2.7134470777726634, 'MC-NNM': -3.062656447106029, 'robust_synthetic_control': -5.861883022845827, 'OLS': -7.441569687989318}
# experiment 72, time elapses  603.6086192131042
# {'De-biased Convex': -5.257258339961943, 'SDID': -10.042422291946743, 'MC-NNM': -5.086494359209681, 'robust_synthetic_control': -0.5558667267774524, 'OLS': -8.481119247934945}
# experiment 73, time elapses  610.8495829105377
# {'De-biased Convex': -4.7914322387151955, 'SDID': -8.284722411884426, 'MC-NNM': -12.948443987365804, 'robust_synthetic_control': -13.620079984702413, 'OLS': -13.265767562931131}
# experiment 74, time elapses  611.3076932430267
# {'De-biased Convex': -0.9024482959706717, 'SDID': -5.5983574569547905, 'MC-NNM': 4.354082547961937, 'robust_synthetic_control': 4.4361800144479915, 'OLS': 3.0540850987974615}
# experiment 75, time elapses  620.0616290569305
# {'De-biased Convex': -2.3150527725290146, 'SDID': -1.3564281038688257, 'MC-NNM': 1.824370625335792, 'robust_synthetic_control': -0.6503002968461828, 'OLS': 3.495073499862812}
# experiment 76, time elapses  622.4799430370331
# {'De-biased Convex': -4.621718849616681, 'SDID': 5.70859104258518, 'MC-NNM': 4.840969318523207, 'robust_synthetic_control': 4.944866492257201, 'OLS': 1.2254340532780574}
# experiment 77, time elapses  627.1202390193939
# {'De-biased Convex': 0.9005638882382669, 'SDID': -8.39829413230525, 'MC-NNM': -2.8883309497173784, 'robust_synthetic_control': -9.313920510935382, 'OLS': -5.036280642554605}
# experiment 78, time elapses  636.0534501075745
# {'De-biased Convex': 1.1820046500231491, 'SDID': 3.6726826877614123, 'MC-NNM': 8.599924178790019, 'robust_synthetic_control': 3.0395117544233976, 'OLS': 13.087584331459727}
# experiment 79, time elapses  641.301647901535
# {'De-biased Convex': -1.119103727149259, 'SDID': -1.087551550378432, 'MC-NNM': -0.48523631669554135, 'robust_synthetic_control': -1.5613937553676536, 'OLS': 2.684760651650688}
# experiment 80, time elapses  644.3304142951965
# {'De-biased Convex': -3.721783202752011, 'SDID': -13.921756023143333, 'MC-NNM': -3.282426689266483, 'robust_synthetic_control': 2.7394212812199044, 'OLS': -6.336683249833452}
# experiment 81, time elapses  649.6198542118073
# {'De-biased Convex': -0.2302433776727142, 'SDID': -3.368097384526145, 'MC-NNM': -0.30262328912067815, 'robust_synthetic_control': -1.4634925142878785, 'OLS': -1.0137029023210928}
# experiment 82, time elapses  659.7467410564423
# {'De-biased Convex': -0.7343372619097366, 'SDID': 2.453750275254908, 'MC-NNM': -0.7301382597531507, 'robust_synthetic_control': -3.1693401977517315, 'OLS': 3.6947680855464533}
# experiment 83, time elapses  663.7484419345856
# {'De-biased Convex': 0.17080993446438697, 'SDID': 4.248611604856958, 'MC-NNM': 5.309709073909122, 'robust_synthetic_control': 2.428704210785252, 'OLS': 13.277767871895303}
# experiment 84, time elapses  663.8959400653839
# {'De-biased Convex': 0.2897422840541992, 'SDID': -0.026098812729511423, 'MC-NNM': 2.3919484516500304, 'robust_synthetic_control': 1.7631329474623776, 'OLS': 3.946689633912346}
# experiment 85, time elapses  671.7154400348663
# {'De-biased Convex': 3.8230867044080945, 'SDID': -15.06231990180973, 'MC-NNM': -19.6265718391426, 'robust_synthetic_control': 9.831086452859068, 'OLS': -20.849714410771988}
# experiment 86, time elapses  682.5185549259186
# {'De-biased Convex': -0.05910752266749597, 'SDID': 3.5248535286470464, 'MC-NNM': -1.170552762712159, 'robust_synthetic_control': 6.263150926879927, 'OLS': 1.6069199491841744}
# experiment 87, time elapses  695.0563201904297
# {'De-biased Convex': -4.2802402852764985, 'SDID': -9.135125122092376, 'MC-NNM': -0.3988900752047293, 'robust_synthetic_control': -1.5866327966703722, 'OLS': -3.7575879791616167}
# experiment 88, time elapses  701.1771399974823
# {'De-biased Convex': -5.371099060503251, 'SDID': -2.962619017630008, 'MC-NNM': 4.37275084069957, 'robust_synthetic_control': -1.0443861989756655, 'OLS': 8.40522560963899}
# experiment 89, time elapses  708.0171711444855
# {'De-biased Convex': -2.2776742377981734, 'SDID': -3.521493130344517, 'MC-NNM': -3.6603323703515116, 'robust_synthetic_control': -0.8860605851439658, 'OLS': -4.159307871641403}
# experiment 90, time elapses  717.0274560451508
# {'De-biased Convex': 0.621846660511121, 'SDID': 1.0100323473793829, 'MC-NNM': 1.323668544097881, 'robust_synthetic_control': -0.1252465400931584, 'OLS': 3.3371886217427686}
# experiment 91, time elapses  722.3094129562378
# {'De-biased Convex': 3.350344882975971, 'SDID': 4.349314954759151, 'MC-NNM': 2.780797732553925, 'robust_synthetic_control': 4.7248957817093356, 'OLS': 5.996280404399641}
# experiment 92, time elapses  730.0215880870819
# {'De-biased Convex': 3.114794436538471, 'SDID': 3.0998303414882464, 'MC-NNM': 4.420838307902116, 'robust_synthetic_control': 3.6299542333400225, 'OLS': 3.64766538574775}
# experiment 93, time elapses  739.7760090827942
# {'De-biased Convex': 1.8591518563429652, 'SDID': 1.2770092095514194, 'MC-NNM': -1.047976635542632, 'robust_synthetic_control': 0.2605651160789506, 'OLS': 0.5669849650242149}
# experiment 94, time elapses  741.4547071456909
# {'De-biased Convex': 1.496533640378928, 'SDID': 1.0527141936350652, 'MC-NNM': 3.985615475269487, 'robust_synthetic_control': 1.955171287543589, 'OLS': 5.6043441299255825}
# experiment 95, time elapses  748.4301891326904
# {'De-biased Convex': 2.714141100573517, 'SDID': 1.8094878545926143, 'MC-NNM': 0.3227062039966633, 'robust_synthetic_control': 0.6929692737154518, 'OLS': 0.5745922322394286}
# experiment 96, time elapses  759.303316116333
# {'De-biased Convex': 11.022663776278215, 'SDID': 3.984747101787857, 'MC-NNM': -10.59216861262572, 'robust_synthetic_control': 7.383246687361378, 'OLS': -13.363087668593536}
# experiment 97, time elapses  766.0976479053497
# {'De-biased Convex': -0.45514494874300837, 'SDID': 4.600348897997346, 'MC-NNM': -0.2694382239879616, 'robust_synthetic_control': 0.10811864576636054, 'OLS': 1.8074339283258105}
# experiment 98, time elapses  773.6563630104065
# {'De-biased Convex': 5.451785143723939, 'SDID': 2.329485857355902, 'MC-NNM': -5.542465727527661, 'robust_synthetic_control': 32.293979493228015, 'OLS': -2.457368745342986}
# experiment 99, time elapses  783.0480511188507

# %%
(np.abs(datas) / tau_star_o).describe()
# Out:
#        De-biased Convex        SDID      MC-NNM  robust_synthetic_control  \
# count        100.000000  100.000000  100.000000                100.000000
# mean           0.101179    0.178583    0.167516                  0.216767
# std            0.084983    0.135128    0.149479                  0.288645
# min            0.000903    0.001092    0.001182                  0.004133
# 25%            0.037007    0.081717    0.057550                  0.061223
# 50%            0.077180    0.147395    0.132094                  0.139841
# 75%            0.148142    0.236364    0.225003                  0.265388
# max            0.461141    0.630143    0.821092                  2.187002
#
#               OLS
# count  100.000000
# mean     0.217179
# std      0.168821
# min      0.001887
# 25%      0.075258
# 50%      0.174847
# 75%      0.305811
# max      0.872263

# %%
M0 = readData.read_data('tobacco')
suggest_r = 5
tau_star_o = np.mean(M0) / 5
datas = tobacco_experiment_performance_run_results(num_experiment = 100, pattern = 'block', suggest_r = suggest_r)
# Out:
# 5.0067901611328125e-06
# experiment  0
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': -0.7961720621223733, 'SDID': -17.211353518873, 'robust_synthetic_control': -4.402694792626679, 'OLS': -14.181068604712726}
# experiment 0, time elapses  0.19588613510131836
# ***sparsity**** 0.011035653650254669
# /var/folders/84/sq9gqqh952qfzb3rpnrkcjqr0000gn/T/ipykernel_2056/2130466035.py:14: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if (treat_units == []):
# {'De-biased Convex': -0.6430926473850125, 'SDID': 3.5849302267763203, 'robust_synthetic_control': -3.8299516812690566, 'OLS': 22.31919016443137}
# experiment 1, time elapses  0.3824329376220703
# ***sparsity**** 0.03310696095076401
# /var/folders/84/sq9gqqh952qfzb3rpnrkcjqr0000gn/T/ipykernel_2056/2130466035.py:14: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if (treat_units == []):
# {'De-biased Convex': 0.38991622437369244, 'SDID': -3.9442202546208556, 'robust_synthetic_control': -16.862091410903524, 'OLS': -14.058980108220021}
# experiment 2, time elapses  0.5848729610443115
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 11.79489257312921, 'SDID': 6.405807808580569, 'robust_synthetic_control': 11.716210583637334, 'OLS': 0.023928976695167137}
# experiment 3, time elapses  0.7609341144561768
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 4.04521953370012, 'SDID': -0.13244318234424668, 'robust_synthetic_control': 3.595779428424173, 'OLS': 0.6524752524776787}
# experiment 4, time elapses  0.938647985458374
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': 3.3512391406441573, 'SDID': -10.474822708677161, 'robust_synthetic_control': -33.306703664252254, 'OLS': -37.700317911904136}
# experiment 5, time elapses  1.1440010070800781
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 0.036322454943253035, 'SDID': 3.8393153335428423, 'robust_synthetic_control': 7.090680283576223, 'OLS': -4.50607318785196}
# experiment 6, time elapses  1.3423740863800049
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 8.84738790673434, 'SDID': 4.281957370552714, 'robust_synthetic_control': 15.832804590703226, 'OLS': -1.4122471960595142}
# experiment 7, time elapses  1.5279819965362549
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 2.8742809690503606, 'SDID': 7.457978321194297, 'robust_synthetic_control': 7.477033792913183, 'OLS': 15.615428245790795}
# experiment 8, time elapses  1.7008099555969238
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': -1.2358235931120838, 'SDID': 7.457843991489543, 'robust_synthetic_control': -1.0302054712043152, 'OLS': -3.4254698736855467}
# experiment 9, time elapses  1.864837884902954
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': -3.3755259114009952, 'SDID': -4.933310514501253, 'robust_synthetic_control': -0.9781298085145558, 'OLS': -2.3453308456589887}
# experiment 10, time elapses  2.0711801052093506
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': -2.280409103225864, 'SDID': -4.201469374372785, 'robust_synthetic_control': -6.44233075984171, 'OLS': -3.7434895081640036}
# experiment 11, time elapses  2.2348830699920654
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 0.517628482503536, 'SDID': -5.728732205990298, 'robust_synthetic_control': -17.147850191147942, 'OLS': -12.497884567947478}
# experiment 12, time elapses  2.4395840167999268
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 3.26400508979696, 'SDID': 2.622758314530735, 'robust_synthetic_control': 9.59116818162996, 'OLS': 9.848279390812586}
# experiment 13, time elapses  2.6008009910583496
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 5.343855864976327, 'SDID': 1.8347705040419022, 'robust_synthetic_control': 2.6346533159321766, 'OLS': -14.214711560329931}
# experiment 14, time elapses  2.8090639114379883
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 1.4425894192936415, 'SDID': 0.7171159386040173, 'robust_synthetic_control': 7.118178343997062, 'OLS': -3.2632228669546466}
# experiment 15, time elapses  3.0117299556732178
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -1.7010406465590204, 'SDID': -0.2675287687121237, 'robust_synthetic_control': -3.416606660343594, 'OLS': 8.306300977918351}
# experiment 16, time elapses  3.2045161724090576
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 4.948097681810971, 'SDID': 8.042040240155409, 'robust_synthetic_control': 13.86198946707205, 'OLS': 6.770272167071155}
# experiment 17, time elapses  3.3803892135620117
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': 4.612796854625792, 'SDID': 0.6409872109169186, 'robust_synthetic_control': -16.00119810216656, 'OLS': -27.187175215229637}
# experiment 18, time elapses  3.6007909774780273
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -5.391187747016389, 'SDID': -6.879790078829327, 'robust_synthetic_control': -9.845569466031833, 'OLS': 7.793137878499888}
# experiment 19, time elapses  3.790043830871582
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 1.619799300985438, 'SDID': 0.30884797623967586, 'robust_synthetic_control': 3.1268414621625134, 'OLS': 8.832225387823659}
# experiment 20, time elapses  3.967867851257324
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 2.2066661429101497, 'SDID': 6.303235690787959, 'robust_synthetic_control': 5.558647976617996, 'OLS': 4.3570484933942755}
# experiment 21, time elapses  4.144587993621826
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': 1.5622500993586677, 'SDID': 8.412506802988435, 'robust_synthetic_control': 4.771752913005745, 'OLS': 12.105842218387416}
# experiment 22, time elapses  4.330410957336426
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': -4.940820959257476, 'SDID': -6.318580353811345, 'robust_synthetic_control': -7.0636199158495145, 'OLS': -13.03640798814813}
# experiment 23, time elapses  4.5378639698028564
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': -0.6496114896086169, 'SDID': 7.772702682765008, 'robust_synthetic_control': 2.9464435486568057, 'OLS': 16.344402921898578}
# experiment 24, time elapses  4.734502077102661
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 4.189301927219574, 'SDID': -3.0949927155974386, 'robust_synthetic_control': 6.42889078094889, 'OLS': -3.1611302895108437}
# experiment 25, time elapses  4.902640104293823
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 1.4389703872757877, 'SDID': -2.3528700194293855, 'robust_synthetic_control': 1.960109661023381, 'OLS': 3.2236973202361483}
# experiment 26, time elapses  5.072039842605591
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': -0.3752961902030876, 'SDID': -6.2184108901397295, 'robust_synthetic_control': -7.129624719647964, 'OLS': -4.365822703347732}
# experiment 27, time elapses  5.241264820098877
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': -1.1506332184521568, 'SDID': 3.499886705368567, 'robust_synthetic_control': -3.6122476616756423, 'OLS': 11.823433135726326}
# experiment 28, time elapses  5.423888206481934
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 0.2578438090738153, 'SDID': 0.08282774323820519, 'robust_synthetic_control': 11.712014051587843, 'OLS': -12.980676510468783}
# experiment 29, time elapses  5.602757930755615
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 2.0511650088679403, 'SDID': -7.795989761936756, 'robust_synthetic_control': 1.6328428773102743, 'OLS': -11.771067511662045}
# experiment 30, time elapses  5.784790992736816
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 1.858159691330787, 'SDID': -1.499375871477092, 'robust_synthetic_control': 4.117749663000627, 'OLS': -0.518544521781223}
# experiment 31, time elapses  5.956421852111816
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 5.1431272243445, 'SDID': 3.47280524393004, 'robust_synthetic_control': 9.913217267939139, 'OLS': 2.1749084248852846}
# experiment 32, time elapses  6.1465840339660645
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': -4.406059479574385, 'SDID': -3.1241481774985402, 'robust_synthetic_control': -8.382384793823931, 'OLS': 0.5752192318857219}
# experiment 33, time elapses  6.360512971878052
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 1.1049500870991267, 'SDID': 2.1540783196726423, 'robust_synthetic_control': 4.8144559686563895, 'OLS': 5.257822018345546}
# experiment 34, time elapses  6.525082111358643
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 0.967640666175253, 'SDID': -9.65167041077531, 'robust_synthetic_control': -13.72493506892236, 'OLS': -23.224650184423062}
# experiment 35, time elapses  6.715363025665283
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -2.188632349927598, 'SDID': -0.8852844179643533, 'robust_synthetic_control': -1.7158283209242917, 'OLS': 1.2304345036884214}
# experiment 36, time elapses  6.906224966049194
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 6.887059025677122, 'SDID': 18.733326366036426, 'robust_synthetic_control': 6.348203415782773, 'OLS': 28.609069178182725}
# experiment 37, time elapses  7.075854063034058
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 3.6794216097985526, 'SDID': 11.221090315998921, 'robust_synthetic_control': 7.878996067834578, 'OLS': -2.2069928770479024}
# experiment 38, time elapses  7.2356860637664795
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -1.0984675216034532, 'SDID': 0.5964659292600842, 'robust_synthetic_control': -6.689104071972984, 'OLS': 9.90873704575285}
# experiment 39, time elapses  7.411180019378662
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 5.017849057706837, 'SDID': 15.26724362377832, 'robust_synthetic_control': 11.986845453749723, 'OLS': 1.2370571278998845}
# experiment 40, time elapses  7.606521129608154
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 0.5126163393753131, 'SDID': 2.7094622403284525, 'robust_synthetic_control': 3.816482808339188, 'OLS': 13.215685023982509}
# experiment 41, time elapses  7.795400857925415
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': -0.7962427432699108, 'SDID': -17.212144334274917, 'robust_synthetic_control': -4.402694792626679, 'OLS': -14.181068604712724}
# experiment 42, time elapses  7.979532957077026
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': -2.9905436624171493, 'SDID': -4.201443734171907, 'robust_synthetic_control': -11.136495910666184, 'OLS': -10.824163330485721}
# experiment 43, time elapses  8.199095010757446
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 2.296567373934163, 'SDID': -9.310042194443746, 'robust_synthetic_control': -17.5893346763011, 'OLS': -17.880850046010767}
# experiment 44, time elapses  8.378849029541016
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -3.9433384993406886, 'SDID': -0.3663953247768621, 'robust_synthetic_control': -8.996739895634285, 'OLS': 2.387758033811533}
# experiment 45, time elapses  8.574217081069946
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 5.40524101410206, 'SDID': 0.8837894398720678, 'robust_synthetic_control': 7.0337670035561, 'OLS': 3.5662332346808157}
# experiment 46, time elapses  8.76037311553955
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': -0.48177925511633646, 'SDID': -5.232307871107224, 'robust_synthetic_control': -1.8146186431906628, 'OLS': 2.382556368949338}
# experiment 47, time elapses  8.939236164093018
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -4.844493448751319, 'SDID': 5.471111550941572, 'robust_synthetic_control': -0.14813192822742494, 'OLS': 5.83204441839548}
# experiment 48, time elapses  9.120483160018921
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 11.662054300465584, 'SDID': 14.387996644762126, 'robust_synthetic_control': 24.406768346022147, 'OLS': -3.7049324841184443}
# experiment 49, time elapses  9.294180154800415
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 6.528591661916739, 'SDID': 0.5862647921612911, 'robust_synthetic_control': -9.899094639203309, 'OLS': -14.816197267578959}
# experiment 50, time elapses  9.521384000778198
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 3.2115570395924635, 'SDID': 1.9307554096897448, 'robust_synthetic_control': 4.302654643799485, 'OLS': 12.484314095759245}
# experiment 51, time elapses  9.694828033447266
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 0.475061417066712, 'SDID': 9.788948354253655, 'robust_synthetic_control': 8.863034032174266, 'OLS': 5.188502629160926}
# experiment 52, time elapses  9.898818016052246
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 3.211235984594069, 'SDID': 1.9326384069208444, 'robust_synthetic_control': 4.302654643799489, 'OLS': 12.484314095759252}
# experiment 53, time elapses  10.078602075576782
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 0.889908719955681, 'SDID': -8.647148272945225, 'robust_synthetic_control': -18.05176559318363, 'OLS': -21.2070381597822}
# experiment 54, time elapses  10.305190801620483
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -3.9265250004152357, 'SDID': -6.1839919215982135, 'robust_synthetic_control': -8.200442066085962, 'OLS': -3.3379234320027074}
# experiment 55, time elapses  10.468366146087646
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 2.1053185135020662, 'SDID': 7.414194657428462, 'robust_synthetic_control': 8.225274932642721, 'OLS': 14.404249948343876}
# experiment 56, time elapses  10.658303022384644
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': -4.464748348116018, 'SDID': 2.964174586711259, 'robust_synthetic_control': -10.069116170949446, 'OLS': -4.4598676923145195}
# experiment 57, time elapses  10.818196058273315
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 2.205787730386156, 'SDID': 7.561244069316203, 'robust_synthetic_control': 5.647652806676071, 'OLS': 10.616793671259046}
# experiment 58, time elapses  10.980608940124512
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': -2.0698709396280535, 'SDID': -1.2609767024481116, 'robust_synthetic_control': -9.644934558720285, 'OLS': -5.758341578376548}
# experiment 59, time elapses  11.170927047729492
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 1.5865281211174853, 'SDID': 1.0842090524678625, 'robust_synthetic_control': -5.036499256369982, 'OLS': 2.8275844813856565}
# experiment 60, time elapses  11.3681001663208
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': -0.07854164833886301, 'SDID': 0.6380439268831282, 'robust_synthetic_control': 2.3178377507590824, 'OLS': 0.5547375657767475}
# experiment 61, time elapses  11.530768871307373
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 6.449244360760368, 'SDID': -7.303139219640343, 'robust_synthetic_control': -13.032701076899762, 'OLS': -18.716576302770044}
# experiment 62, time elapses  11.726737976074219
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 1.450618775953199, 'SDID': 0.12497222136731878, 'robust_synthetic_control': -7.745083242261154, 'OLS': -6.905360641446926}
# experiment 63, time elapses  11.920396089553833
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 0.49092797230395036, 'SDID': -2.4349348924732723, 'robust_synthetic_control': 0.23083902136304602, 'OLS': -6.142689196907508}
# experiment 64, time elapses  12.088940143585205
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -4.069324277853859, 'SDID': -1.8119181943171299, 'robust_synthetic_control': -6.385880860074696, 'OLS': 6.627462688530883}
# experiment 65, time elapses  12.27432918548584
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': 0.22254684784835987, 'SDID': 0.6403743892236875, 'robust_synthetic_control': 2.317837750759086, 'OLS': 0.5547375657767439}
# experiment 66, time elapses  12.437559127807617
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': -2.961430441942465, 'SDID': -2.683243268760272, 'robust_synthetic_control': -1.371286754706226, 'OLS': 0.9853806395108151}
# experiment 67, time elapses  12.619611024856567
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': -1.0712453128336463, 'SDID': 1.9567006257026307, 'robust_synthetic_control': -3.4915586240155747, 'OLS': 10.771738574458134}
# experiment 68, time elapses  12.797606229782104
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': -13.235269127155334, 'SDID': -7.239905479461239, 'robust_synthetic_control': -36.857497117156626, 'OLS': -33.59831571881179}
# experiment 69, time elapses  13.026176929473877
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': 1.557655830862732, 'SDID': -0.1025110332640331, 'robust_synthetic_control': 1.4319374935839555, 'OLS': 2.7860625614473875}
# experiment 70, time elapses  13.194139957427979
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': -6.371159307601435, 'SDID': -6.9207981745229254, 'robust_synthetic_control': -12.445024442171773, 'OLS': -8.1163722551632}
# experiment 71, time elapses  13.362549066543579
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 4.389352694716994, 'SDID': 3.8996793956169356, 'robust_synthetic_control': 2.2716021635220116, 'OLS': 10.180160561712725}
# experiment 72, time elapses  13.554795980453491
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': 1.7705680854202086, 'SDID': 10.158765941495314, 'robust_synthetic_control': 5.162261000542895, 'OLS': 15.833438316987333}
# experiment 73, time elapses  13.741765022277832
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 1.1796398510101227, 'SDID': -0.7605244809050724, 'robust_synthetic_control': 5.0050366420346855, 'OLS': 3.5104376416110163}
# experiment 74, time elapses  13.919359922409058
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': 5.0018735783552515, 'SDID': 0.38685368687524857, 'robust_synthetic_control': -6.543930895163253, 'OLS': 0.9065890762635718}
# experiment 75, time elapses  14.070862054824829
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -3.822034430845097, 'SDID': -0.38071991489068857, 'robust_synthetic_control': -6.914654555958402, 'OLS': 9.898684121864308}
# experiment 76, time elapses  14.260451078414917
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': -0.11341292971385286, 'SDID': 1.384871278909273, 'robust_synthetic_control': -1.40694488442659, 'OLS': 10.893307782248172}
# experiment 77, time elapses  14.431195259094238
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': -4.464531480812809, 'SDID': 2.9494824962629522, 'robust_synthetic_control': -10.069116170949439, 'OLS': -4.459867692314518}
# experiment 78, time elapses  14.57787013053894
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 0.6934279868902209, 'SDID': 8.869220078432221, 'robust_synthetic_control': 9.439555564886177, 'OLS': -10.004079328282174}
# experiment 79, time elapses  14.7764310836792
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 0.628309783352087, 'SDID': 14.320085395890942, 'robust_synthetic_control': 10.166823681344432, 'OLS': 11.60431916012519}
# experiment 80, time elapses  14.958055019378662
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 5.018131552114294, 'SDID': 15.26666036884205, 'robust_synthetic_control': 11.98684545374972, 'OLS': 1.2370571278999094}
# experiment 81, time elapses  15.150923013687134
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': 0.8229667071569953, 'SDID': 8.664764209314288, 'robust_synthetic_control': 0.8385063315249468, 'OLS': 17.191518926021168}
# experiment 82, time elapses  15.32555103302002
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': -0.5060137753578822, 'SDID': -4.1990214900287945, 'robust_synthetic_control': -4.405783595985444, 'OLS': 1.1482511373275912}
# experiment 83, time elapses  15.511415004730225
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 1.5347711943911513, 'SDID': 1.9656984983983712, 'robust_synthetic_control': 1.686238936903834, 'OLS': 10.976482665774395}
# experiment 84, time elapses  15.705708980560303
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 4.167511701190467, 'SDID': -2.313033493239466, 'robust_synthetic_control': -0.9248931860819809, 'OLS': -3.267088983680317}
# experiment 85, time elapses  15.87041687965393
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': -0.730826266075411, 'SDID': -10.753041020457307, 'robust_synthetic_control': -4.621091223095124, 'OLS': -2.82584218340401}
# experiment 86, time elapses  16.032453775405884
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': -2.4312242943775093, 'SDID': -5.894138644555687, 'robust_synthetic_control': -17.40608830148716, 'OLS': -15.158023094606012}
# experiment 87, time elapses  16.24743914604187
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': -6.038842484246601, 'SDID': -3.2627972041340207, 'robust_synthetic_control': -8.489653172232757, 'OLS': -1.920402482994108}
# experiment 88, time elapses  16.433043956756592
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': 0.06569997973799424, 'SDID': -0.008064898822953026, 'robust_synthetic_control': -10.657831496443197, 'OLS': -21.493039993617295}
# experiment 89, time elapses  16.678043127059937
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -4.922243468803348, 'SDID': -8.500256912707231, 'robust_synthetic_control': -31.52965844186246, 'OLS': -26.158391649782708}
# experiment 90, time elapses  16.88650393486023
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -0.010863041316696354, 'SDID': 4.617945517459312, 'robust_synthetic_control': -2.591402753037281, 'OLS': 12.431092979573236}
# experiment 91, time elapses  17.072277069091797
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -4.016592108331963, 'SDID': -8.081742926419352, 'robust_synthetic_control': -5.864778995872854, 'OLS': -0.24193219506503283}
# experiment 92, time elapses  17.253348112106323
# ***sparsity**** 0.022071307300509338
# {'De-biased Convex': -5.749858595741795, 'SDID': 1.860471835051733, 'robust_synthetic_control': 2.2215253839973705, 'OLS': 1.007182520928378}
# experiment 93, time elapses  17.453328132629395
# ***sparsity**** 0.011035653650254669
# {'De-biased Convex': -9.70789783836715, 'SDID': -8.68642494836558, 'robust_synthetic_control': -9.299907080804754, 'OLS': 0.7217882728204295}
# experiment 94, time elapses  17.633203983306885
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': -1.2145212088732649, 'SDID': 6.73870710900411, 'robust_synthetic_control': 2.730766256445591, 'OLS': 8.097352575335826}
# experiment 95, time elapses  17.83944010734558
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 4.05658415081443, 'SDID': 7.061055899690864, 'robust_synthetic_control': 8.45905244643805, 'OLS': 9.461691510859673}
# experiment 96, time elapses  18.020194053649902
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -1.177368508169927, 'SDID': 7.860888431331773, 'robust_synthetic_control': 5.836087270430845, 'OLS': -0.6211594162145762}
# experiment 97, time elapses  18.22943687438965
# ***sparsity**** 0.03310696095076401
# {'De-biased Convex': -0.9241830896163208, 'SDID': -2.411538906399443, 'robust_synthetic_control': -2.0377592847475157, 'OLS': 1.6272930067347708}
# experiment 98, time elapses  18.408738136291504
# ***sparsity**** 0.044142614601018676
# {'De-biased Convex': 0.6563916991813699, 'SDID': 3.0626655110368866, 'robust_synthetic_control': 7.166787135652424, 'OLS': 8.93928797130804}
# experiment 99, time elapses  18.59463906288147

# %%
(np.abs(datas) / tau_star_o).describe()
# Out:
#        De-biased Convex        SDID  robust_synthetic_control         OLS
# count        100.000000  100.000000                100.000000  100.000000
# mean           0.124280    0.215341                  0.325753    0.370642
# std            0.111113    0.180700                  0.276591    0.324225
# min            0.000454    0.000337                  0.006197    0.001001
# 25%            0.038305    0.077565                  0.145288    0.117805
# 50%            0.091922    0.170339                  0.271645    0.307461
# 75%            0.184942    0.318542                  0.414284    0.527908
# max            0.553707    0.783723                  1.541961    1.577221
